# %% [markdown]
# # Definición de funciones

# %%
# %display latex

#Definición de variables

var('x y z t')                            #Coordenadas y tiempo
a = var(r'alpha')                         #Parámetro de deformación

#Densidad en equilibrio

n_eq= 1-x^2-y^2-(sqrt(8))^2*z^2

nxz(x,z)=n_eq.substitute(y==0)            #Plano xz
nyz(y,z)=n_eq.substitute(x==0)            #Plano yz
nxy(x,y)=n_eq.substitute(z==0)            #Plano xy

#Modos dipolares

n_111 = sqrt(3/pi)/2*x                    #l=1, m=1
n_112 = sqrt(3/pi)/2*y                    #l=1, m=-1
n_10 = sqrt(3/pi)/2*z                     #l=1, m=0

#Modos cuadrupolares

n_221 = sqrt(15/pi)/4*(x^2-y^2)           #l=2, m=2
n_222 = sqrt(15/pi)/2*x*y                 #l=2, m=-2
n_211 = sqrt(15/pi)/2*x*z                 #l=2, m=1
n_212 = sqrt(15/pi)/2*y*z                 #l=2, m=-1
n_20 = -(3/2*a^2+1/2*sqrt(9*a^4-16*a^2+16))/(2+3/2*a^2+1/2*sqrt(9*a^4-16*a^2+16))+x^2+y^2+(-2+3/2*a^2+1/2*sqrt(9*a^4-16*a^2+16))*z^2
n_00 = -(3/2*a^2-1/2*sqrt(9*a^4-16*a^2+16))/(2+3/2*a^2-1/2*sqrt(9*a^4-16*a^2+16))+x^2+y^2+(-2+3/2*a^2-1/2*sqrt(9*a^4-16*a^2+16))*z^2

n_000 = n_00.substitute(a==sqrt(8))       #l=0, m=0
n_200 = n_20.substitute(a==sqrt(8))       #l=2, m=0

# %% [markdown]
# # Densidad en equilibrio

# %%
def Nxz(x,z): 
    if nxz(x,z)>=0:
        return nxz(x,z)
    else: 
        return 0
    
def Nyz(y,z): 
    if nyz(y,z)>=0:
        return nyz(y,z)
    else: 
        return 0
    
def Nxy(x,y): 
    if nxy(x,y)>=0:
        return nxy(x,y)
    else: 
        return 0

# %%
contour_plot(Nxz, (x,-2,2),(z,-0.5,0.5),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(Nyz, (y,-2,2),(z,-0.5,0.5),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(Nxy, (x,-2,2),(y,-2,2),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# # Modos dipolares

# %% [markdown]
# # Modo l=1, m=1

# %%
L1M1(x,z,t) = 2*n_111*sin(t)

def L1M11(x,z): 
    if nxz(x,z)+L1M1(x,z,pi/2)>=0:
        return nxz(x,z)+L1M1(x,z,pi/2)
    else: 
        return 0
    
def L1M12(x,z): 
    if nxz(x,z)+L1M1(x,z,3*pi/2)>=0:
        return nxz(x,z)+L1M1(x,z,3*pi/2)
    else: 
        return 0

# %%
contour_plot(L1M11, (x,-2,2),(z,-0.5,0.5),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(L1M12, (x,-2,2),(z,-0.5,0.5),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# # Modo l=1, m=-1

# %%
L1M_1(y,z,t) = 2*n_112*sin(t)

def L1M112(y,z): 
    if nyz(y,z)+L1M_1(y,z,pi/2)>=0:
        return nyz(y,z)+L1M_1(y,z,pi/2)
    else: 
        return 0
    
def L1M122(y,z): 
    if nyz(y,z)+L1M_1(y,z,3*pi/2)>=0:
        return nyz(y,z)+L1M_1(y,z,3*pi/2)
    else: 
        return 0

# %%
contour_plot(L1M112, (y,-2,2),(z,-0.5,0.5),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(L1M122, (y,-2,2),(z,-0.5,0.5),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# # Modo l=1, m=0

# %%
L1M0(x,z,t) = 2.5*n_10*sin(t)

def L1M01(x,z): 
    if nxz(x,z)+L1M0(x,z,pi/2)>=0:
        return nxz(x,z)+L1M0(x,z,pi/2)
    else: 
        return 0
    
def L1M02(x,z): 
    if nxz(x,z)+L1M0(x,z,3*pi/2)>=0:
        return nxz(x,z)+L1M0(x,z,3*pi/2)
    else: 
        return 0

# %%
contour_plot(L1M01, (x,-2,2),(z,-0.5,0.5),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(L1M02, (x,-2,2),(z,-0.5,0.5),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# # Modos cuadrupolares

# %% [markdown]
# # Modo l=2, m=0

# %%
L2M0(x,z,t) = 0.2*n_200.substitute(y==0)*sin(t)

def L2M01(x,z): 
    if nxz(x,z)+L2M0(x,z,pi/2)>=0:
        return nxz(x,z)+L2M0(x,z,pi/2)
    else: 
        return 0
    
def L2M02(x,z): 
    if nxz(x,z)+L2M0(x,z,3*pi/2)>=0:
        return nxz(x,z)+L2M0(x,z,3*pi/2)
    else: 
        return 0

# %%
contour_plot(L2M01, (x,-2,2),(z,-0.5,0.5),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(L2M02, (x,-2,2),(z,-0.5,0.5),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# # Modo l=0, m=0

# %%
L0M0(x,z,t) = 0.8*n_000.substitute(y==0)*sin(t)

def L0M01(x,z): 
    if nxz(x,z)+L0M0(x,z,pi/2)>=0:
        return nxz(x,z)+L0M0(x,z,pi/2)
    else: 
        return 0
    
def L0M02(x,z): 
    if nxz(x,z)+L0M0(x,z,3*pi/2)>=0:
        return nxz(x,z)+L0M0(x,z,3*pi/2)
    else: 
        return 0

# %%
contour_plot(L0M01, (x,-2,2),(z,-0.5,0.5),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(L0M02, (x,-2,2),(z,-0.5,0.5),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# # Modo l=2, m=2

# %%
L2M2(x,y,t) = n_221*sin(t)

def L2M21(x,y): 
    if nxy(x,y)+L2M2(x,y,pi/2)>=0:
        return nxy(x,y)+L2M2(x,y,pi/2)
    else: 
        return 0
    
def L2M22(x,y): 
    if nxy(x,y)+L2M2(x,y,3*pi/2)>=0:
        return nxy(x,y)+L2M2(x,y,3*pi/2)
    else: 
        return 0

# %%
contour_plot(L2M21, (x,-2,2),(y,-2,2),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(L2M22, (x,-2,2),(y,-2,2),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# # Modo l=2, m=-2

# %%
L2M_2(x,y,t) = n_222*sin(t)

def L2M212(x,y): 
    if nxy(x,y)+L2M_2(x,y,pi/2)>=0:
        return nxy(x,y)+L2M_2(x,y,pi/2)
    else: 
        return 0
    
def L2M222(x,y): 
    if nxy(x,y)+L2M_2(x,y,3*pi/2)>=0:
        return nxy(x,y)+L2M_2(x,y,3*pi/2)
    else: 
        return 0

# %%
contour_plot(L2M212, (x,-2,2),(y,-2,2),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(L2M222, (x,-2,2),(y,-2,2),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# # Modo l=2, m=1

# %%
L2M1(x,z,t) = n_211*sin(t)

def L2M11(x,z): 
    if nxz(x,z)+L2M1(x,z,pi/2)>=0:
        return nxz(x,z)+L2M1(x,z,pi/2)
    else: 
        return 0
    
def L2M12(x,z): 
    if nyz(x,z)+L2M1(x,z,3*pi/2)>=0:
        return nyz(x,z)+L2M1(x,z,3*pi/2)
    else: 
        return 0

# %%
contour_plot(L2M11, (x,-2,2),(z,-0.5,0.5),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(L2M12, (x,-2,2),(z,-0.5,0.5),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# # Modo l=2, m=-1

# %%
L2M12(y,z,t) = n_212*sin(t)

def L2M112(y,z): 
    if nyz(y,z)+L2M12(y,z,pi/2)>=0:
        return nyz(y,z)+L2M12(y,z,pi/2)
    else: 
        return 0
    
def L2M122(y,z): 
    if nyz(y,z)+L2M12(y,z,3*pi/2)>=0:
        return nyz(y,z)+L2M12(y,z,3*pi/2)
    else: 
        return 0

# %%
contour_plot(L2M112, (y,-2,2),(z,-0.5,0.5),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(L2M122, (y,-2,2),(z,-0.5,0.5),plot_points=200, cmap = 'jet')
# Out:
# Graphics object consisting of 1 graphics primitive
